# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import random

# %%
#constants
PATH = r'/content/drive/My Drive/MiniProject_special_topic/dataset/trainingDataset.txt'
factor = 400 #don't make it less than 100
random.seed(30)

# %%
fp = open(PATH, "w")

# %%
for j in range(factor//50):
  for i in range(97,123):
      s="one integer "+chr(i)+';'+chr(i)+" = (int)input()"+'\n'
      fp.write(s)

# %%
for _ in range(factor//50):
  fp.write("Each test case;for _ in range(t)\n")
  fp.write("each test case;for _ in range(t)\n")

# %%
for _ in range(factor//50):
  for i in range(97,123):
    s=chr(i)+" lines;"+"for _ in range("+chr(i)+'):'+'\n'
    fp.write(s)

# %%
for _ in range(factor//50):
  for i in range(97,123):
    s=chr(i)+" lines follow;"+"for _ in range("+chr(i)+'):'+'\n'
    fp.write(s)

# %%
for _ in range(factor):
	a=random.randint(97,97+25)
	b=random.randint(97,97+25)
	if(a!=b):
		s="two integers "+chr(a)+" and "+chr(b)+";"+chr(a)+","+chr(b)+" = list(map(int,input().split()))\n"
		# print(s)
		fp.write(s)

# %%
for _ in range(factor):
	a=random.randint(97,97+25)
	b=random.randint(97,97+25)
	c=random.randint(97,97+25)
	if(a!=b and b!=c and a!=c):
		s="integers "+chr(a)+","+chr(b)+" and "+chr(c)+";"+chr(a)+","+chr(b)+","+chr(c)+" = list(map(int,input().split()))\n"
		# print(s)
		fp.write(s)

# %%
for _ in range(factor):
	a=random.randint(97,97+25)
	b=random.randint(97,97+25)
	c=random.randint(97,97+25)
	if(a!=b and b!=c and a!=c):
		s="integers "+chr(a)+", "+chr(b)+" and "+chr(c)+";"+chr(a)+","+chr(b)+","+chr(c)+" = list(map(int,input().split()))\n"
		# print(s)
		fp.write(s)

# %%
for _ in range(factor):
	a=random.randint(97,97+25)
	b=random.randint(97,97+25)
	c=random.randint(97,97+25)
	if(a!=b and b!=c and a!=c):
		s="three integers "+chr(a)+", "+chr(b)+" and "+chr(c)+";"+chr(a)+","+chr(b)+","+chr(c)+" = list(map(int,input().split()))\n"
		# print(s)
		fp.write(s)

# %%
for _ in range(factor):
	a=random.randint(97,97+25)
	b=random.randint(97,97+25)
	c=random.randint(97,97+25)
	if(a!=b and b!=c and a!=c):
		s="integers "+chr(a)+"i,"+chr(b)+"i and "+chr(c)+"i;"+chr(a)+","+chr(b)+","+chr(c)+" = list(map(int,input().split()))\n"
		# print(s)
		fp.write(s)

# %%
for _ in range(factor):
  l=chr(random.randint(97,122))
  m=chr(random.randint(97,122))
  if(l!=m):
    fp.write(l+" integers "+m+"1"+","+m+"2"+",…,"+m+"n"+";"+m+"=list(map(int,input().split()))\n")

# %%
for _ in range(factor):
  l=chr(random.randint(97,122))
  m=chr(random.randint(97,122))
  if(l!=m):
    fp.write(l+" integers "+m+"1"+","+m+"2"+",...,"+m+"n"+";"+m+"=list(map(int,input().split()))\n")

# %%
for _ in range(factor):
  l=chr(random.randint(97,122))
  m=chr(random.randint(97,122))
  if(l!=m):
    fp.write("string "+l+" of length "+m+";"+l+"=input()\n")

# %%
for _ in range(factor):
  l=chr(random.randint(97,122))
  m=chr(random.randint(97,122))
  if(l!=m):
    fp.write("string "+l+";"+l+"=input()\n")

# %%
for _ in range(factor//50):
  for i in range(97,122):
    fp.write("one positive integer "+chr(i)+";"+chr(i)+"=int(input())\n")

# %%
for i in range(factor):
  l=chr(random.randint(97,122))
  m=chr(random.randint(97,122))
  fp.write("two positive integers "+l+","+m+";"+l+","+m+"=list(map(int,input().split()))\n")

# %%
for _ in range(factor):
  a = chr(random.randint(97,122))
  b = chr(random.randint(97,122))
  c = chr(105+random.randint(0,1))
  if(a!=b):
    fp.write(a+" integer "+b+c+';'+b+"=list(map(int,input().split()))\n")

# %%
for _ in range(factor//50):
  fp.write("t test cases;for _ in range(t):\n")
  fp.write("test case;for _ in range(t):\n")
  fp.write("integer t test cases;for _ in range(t):\n")

# %%
for i in range(factor):
  l=chr(random.randint(97,122))
  m=chr(random.randint(97,122))
  fp.write("integers "+l+","+m+";"+l+","+m+"=list(map(int,input().split()))\n")

# %%
for i in range(factor):
  l=chr(random.randint(97,122))
  m=chr(random.randint(97,122))
  fp.write("integers "+l+" and "+m+";"+l+","+m+"=list(map(int,input().split()))\n")

# %%
for _ in range(factor//50):
  for i in range(97,122):
    fp.write("integer "+chr(i)+";"+chr(i)+"=int(input())\n")

# %% [markdown]
# new additions

# %%
for _ in range(factor):
	a=random.randint(97,97+25)
	b=random.randint(97,97+25)
	c=random.randint(97,97+25)
	d=random.randint(97,97+25)
	if(a!=b and b!=c and a!=c and d!=a and d!=c):
		s="integers "+chr(a)+", "+chr(b)+", "+chr(c)+" and "+chr(d)+";"+chr(a)+","+chr(b)+","+chr(c)+","+chr(d)+" = list(map(int,input().split()))\n"
		# print(s)
		fp.write(s)

# %%
fp.close()
